# %% [markdown]
# # Practical Visualization Examples

# %% [markdown]
# Line Plot to Show Trends Over Time (flights)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = sns.load_dataset('tips')
data.head()
sns.set_theme(style="ticks", palette="pastel")
sns.lineplot(x="total_bill", y="tip", data=data)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Scatter Plot to Visualize Relationships Between Two Variables (tips)

# %%
sns.scatterplot(x="total_bill", y="tip", data=data)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Bar Plot to Show Categorical Data  (tips)

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=data)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Histogram to Show Data Distribution (tips)

# %%
sns.histplot(data['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# Box Plot to Visualize Distribution and Outliers (tips)

# %%
sns.boxplot(x="day", y="total_bill", data=data)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Violin Plot to Show Density and Distribution (tips)

# %%
sns.violinplot(x="day", y="total_bill", data=data)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Pair Plot to Show Pairwise Relationships (tips)

# %%
sns.pairplot(data, hue="sex", palette="pastel")

# %% [markdown]
# Count Plot to Show the Frequency of Categorical Values (tips)

# %%
sns.countplot(x="total_bill", data=data)
# Out:
# C:\Users\amrrrr\AppData\Local\Temp\ipykernel_32408\649615043.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="total_bill", data=data, palette="pastel")
# <Axes: xlabel='total_bill', ylabel='count'>

# %% [markdown]
# Joint Plot to Show Distribution and Relationship (tips)

# %%
sns.jointplot(x="total_bill", y="tip", data=data, kind="scatter")
